# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('PCOS.xlsx')

# %%
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#          BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.300000           15                78                22  ...
# 1  24.921163           15                74                20  ...
# 2  25.270891           11                72                18  ...
# 3  29.674945           13                72                20  ...
# 4  20.060954           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
df.columns
# Out:
# Index(['Sl. No', 'Patient File No.', 'PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ',
#        'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions',
#        '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)',
#        'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio',
#        'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)',
#        'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)',
#        'Unnamed: 44'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   BMI                     541 non-null    float64
#  7   Blood Group             541 non-null    int64
#  8   Pulse rate(bpm)         541 non-null    int64
#  9   RR (breaths/min)        541 non-null    int64
#  10  Hb(g/dl)                541 non-null    float64
#  11  Cycle(R/I)              541 non-null    int64
#  12  Cycle length(days)      541 non-null    int64
#  13  Marraige Status (Yrs)   540 non-null    float64
# ...

# %%
df.corr()
# Out:
#                           Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  \
# Sl. No                  1.000000          1.000000    0.060998    0.067133
# Patient File No.        1.000000          1.000000    0.060998    0.067133
# PCOS (Y/N)              0.060998          0.060998    1.000000   -0.168513
#  Age (yrs)              0.067133          0.067133   -0.168513    1.000000
# Weight (Kg)            -0.082823         -0.082823    0.211938   -0.029734
# Height(Cm)             -0.011700         -0.011700    0.068254   -0.119819
# BMI                    -0.083578         -0.083578    0.199534    0.021261
# Blood Group             0.001705          0.001705    0.036433   -0.010954
# Pulse rate(bpm)        -0.044533         -0.044533    0.091821    0.045831
# RR (breaths/min)       -0.015196         -0.015196    0.036928    0.087382
# Hb(g/dl)               -0.088681         -0.088681    0.087170   -0.021558
# ...

# %%
df.columns
# Out:
# Index(['Sl. No', 'Patient File No.', 'PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ',
#        'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions',
#        '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)',
#        'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio',
#        'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)',
#        'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)',
#        'Unnamed: 44'],
#       dtype='object')

# %%
df2=df[['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)','Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ','Cycle(R/I)', 'Cycle length(days)','Pregnant(Y/N)', 'FSH(mIU/mL)',
       'LH(mIU/mL)', 'FSH/LH','Weight gain(Y/N)', 'hair growth(Y/N)','Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)','Reg.Exercise(Y/N)','Endometrium (mm)','Follicle No. (L)', 'Follicle No. (R)']]

# %%
df2.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)         BMI  Blood Group  \
# 0           0          28         44.6        152.0  19.300000           15
# 1           0          36         65.0        161.5  24.921163           15
# 2           1          33         68.8        165.0  25.270891           11
# 3           0          37         65.0        148.0  29.674945           13
# 4           0          25         52.0        161.0  20.060954           11
#
#    Pulse rate(bpm)   Cycle(R/I)  Cycle length(days)  Pregnant(Y/N)  ...  \
# 0                78           2                   5              0  ...
# 1                74           2                   5              1  ...
# 2                72           2                   5              1  ...
# 3                72           2                   5              0  ...
# 4                72           2                   5              1  ...
#
#      FSH/LH  Weight gain(Y/N)  hair growth(Y/N)  Skin darkening (Y/N)  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PCOS (Y/N)            541 non-null    int64
#  1    Age (yrs)            541 non-null    int64
#  2   Weight (Kg)           541 non-null    float64
#  3   Height(Cm)            541 non-null    float64
#  4   BMI                   541 non-null    float64
#  5   Blood Group           541 non-null    int64
#  6   Pulse rate(bpm)       541 non-null    int64
#  7   Cycle(R/I)            541 non-null    int64
#  8   Cycle length(days)    541 non-null    int64
#  9   Pregnant(Y/N)         541 non-null    int64
#  10  FSH(mIU/mL)           541 non-null    float64
#  11  LH(mIU/mL)            541 non-null    float64
#  12  FSH/LH                541 non-null    float64
#  13  Weight gain(Y/N)      541 non-null    int64
#  14  hair growth(Y/N)      541 non-null    int64
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df2.drop('PCOS (Y/N)',axis=1)
y=df2['PCOS (Y/N)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (362, 21)

# %%
y_test.shape
# Out:
# (179,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction=rfc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(prediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       131
#            1       0.76      0.92      0.83        48
#
#     accuracy                           0.90       179
#    macro avg       0.86      0.90      0.88       179
# weighted avg       0.91      0.90      0.90       179

# %%
confusion_matrix(prediction,y_test)
# Out:
# array([[117,  14],
#        [  4,  44]], dtype=int64)

# %%
from joblib import Parallel, delayed
import joblib
joblib.dump(rfc, 'PCOS.pkl')
# Out:
# ['PCOS.pkl']

# %%
model=joblib.load('PCOS.pkl')

# %%
df2.shape
# Out:
# (541, 22)

# %%
data={' Age (yrs)':30, 'Weight (Kg)':[40],'Height(Cm) ':[153], 'BMI':[19.30], 'Blood Group':[15], 'Pulse rate(bpm) ':[78],'Cycle(R/I)':[2], 'Cycle length(days)':[5],'Pregnant(Y/N)':[1], 'FSH(mIU/mL)':[2.16],
      'LH(mIU/mL)':[14.3],
      'FSH/LH':[2.16],'Weight gain(Y/N)':[0], 'hair growth(Y/N)':[0],'Skin darkening (Y/N)':[1], 'Hair loss(Y/N)':[0], 'Pimples(Y/N)':0,'Reg.Exercise(Y/N)':1,'Endometrium (mm)':7.0,'Follicle No. (L)':3, 'Follicle No. (R)':[5]}

# %%
df7=pd.DataFrame(data)

# %%
df7
# Out:
#     Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   \
# 0          30           40          153  19.3           15                78
#
#    Cycle(R/I)  Cycle length(days)  Pregnant(Y/N)  FSH(mIU/mL)  ...  FSH/LH  \
# 0           2                   5              1         2.16  ...    2.16
#
#    Weight gain(Y/N)  hair growth(Y/N)  Skin darkening (Y/N)  Hair loss(Y/N)  \
# 0                 0                 0                     1               0
#
#    Pimples(Y/N)  Reg.Exercise(Y/N)  Endometrium (mm)  Follicle No. (L)  \
# 0             0                  1               7.0                 3
#
#    Follicle No. (R)
# 0                 5
#
# [1 rows x 21 columns]

# %%
rf=model.predict(df7)
if(rf==0):
    print("Not infected")
else:
    print("Infected")
# Out:
# Not infected

# %%
import sklearn
sklearn.__version__
# Out:
# '1.2.2'

# %%
import pickle

with open('PCOS.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
import pickle
import numpy as np

# Load the .pkl file
with open('PCOS.pkl', 'rb') as f:
    model_weights = pickle.load(f)

# Print the shape and values of the NumPy array
print(model_weights.shape)
print(model_weights)
# Out:
# (21,)
# [' Age (yrs)' 'Weight (Kg)' 'Height(Cm) ' 'BMI' 'Blood Group'
#  'Pulse rate(bpm) ' 'Cycle(R/I)' 'Cycle length(days)' 'Pregnant(Y/N)'
#  'FSH(mIU/mL)' 'LH(mIU/mL)' 'FSH/LH' 'Weight gain(Y/N)' 'hair growth(Y/N)'
#  'Skin darkening (Y/N)' 'Hair loss(Y/N)' 'Pimples(Y/N)'
#  'Reg.Exercise(Y/N)' 'Endometrium (mm)' 'Follicle No. (L)'
#  'Follicle No. (R)']
